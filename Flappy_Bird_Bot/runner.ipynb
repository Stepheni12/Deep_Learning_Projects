# %%
from keras.models import load_model
import numpy as np
import cv2
from mss import mss
from PIL import Image
import pyautogui as pya

model = load_model("model")
bbox = {'top': 140, 'left': 710, 'width': 480, 'height': 610}
sct = mss()
training_data = []

while 1:
    sct_img = sct.grab(bbox)
    black_img = cv2.cvtColor(np.array(sct_img), cv2.COLOR_BGR2GRAY)
    img = cv2.resize(black_img, (480,270))
    img = img.reshape(1,270,480,1)
    pred = model.predict(img)
    if pred[0].argmax() == 0:
        pya.press('space')
# Out:
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f8873fde1fcd> in <module>()
#      12
#      13 while 1:
# ---> 14     sct_img = sct.grab(bbox)
#      15     black_img = cv2.cvtColor(np.array(sct_img), cv2.COLOR_BGR2GRAY)
#      16     img = cv2.resize(black_img, (480,270))
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\mss\windows.py in grab(self, monitor)
#     293             monitor["left"],
#     294             monitor["top"],
# --> 295             SRCCOPY | CAPTUREBLT,
#     296         )
#     297         bits = self.gdi32.GetDIBits(
#
# KeyboardInterrupt:
